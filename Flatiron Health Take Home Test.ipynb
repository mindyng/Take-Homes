# %% [markdown]
# # General Questions

# %% [markdown]
# (1) When presented with a new dataset or database, the steps I generally take to evaluate it prior to working with it:
#
# 1. What information does it provide?
# 2. Does the data give me enough information to answer my question/solve my problem?
# 3. If the dataset does not have all the information I need, are there any data tables that can be brought together to give a richer dataset?
#
#  After confirming that and prior to setting up for a test:
#
#
# 4. If the dataset has the information I need, how large is the data so that it is statistically significant?
# 5. Are there any NaN's that need to be filtered out?
# 6. What are the overall statistics of the numerical data?
# 7. Are there any outliers that need to be taken out?
# 8. Are there similar features that would produce multicollinearity?
# 9. Does the data need to be rescaled?
#
# (2) Based on the information provided and the attached dataset, the three questions I would like to understand prior to conducting any analysis of the data is:
#
# 1. How sick are the patients (early stage/late stage)?
# 2. Are the patients taking any other drugs besides those listed?
# 3. How much of the drugs are given?

# %% [markdown]
# # Data Analysis Questions

# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import plotly.plotly as py
import cufflinks as cf
from plotly import figure_factory as FF
import scipy

# %%
#Reading in Patient_Diagnosis data

diagnosis = pd.read_csv("Patient_Diagnosis.csv")

# %%
diagnosis.head(10)
# Out:
#    patient_id diagnosis_date  diagnosis_code      diagnosis
# 0        2120         1/9/10           174.1  Breast Cancer
# 1        2720         1/9/10           174.1  Breast Cancer
# 2        2038        1/21/10           174.9  Breast Cancer
# 3        2238        1/21/10           174.9  Breast Cancer
# 4        2175        2/17/10           174.7  Breast Cancer
# 5        2475        2/17/10           174.7  Breast Cancer
# 6        2407        6/13/10           174.9  Breast Cancer
# 7        2607        6/13/10           174.9  Breast Cancer
# 8        2425       12/15/10           174.9  Breast Cancer
# 9        3025       12/15/10           174.9  Breast Cancer

# %%
diagnosis.tail()
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis
# 52        8480        5/16/13           174.3  Breast Cancer
# 53        8615        7/18/13           174.7  Breast Cancer
# 54        8827        7/21/13           174.9  Breast Cancer
# 55        9489        8/19/13           174.9  Breast Cancer
# 56        9331        8/23/13           174.9  Breast Cancer

# %%
diagnosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
# patient_id        57 non-null int64
# diagnosis_date    57 non-null object
# diagnosis_code    57 non-null float64
# diagnosis         57 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.9+ KB

# %%
#Reading in Patient_Treatment data

treatment = pd.read_csv("Patient_Treatment.csv")

# %%
treatment.head(10)
# Out:
#    patient_id treatment_date drug_code
# 0        2720        1/20/10         B
# 1        2238        1/21/10         B
# 2        2120        1/23/10         B
# 3        2038        1/24/10         A
# 4        2120        1/24/10         A
# 5        2038        1/24/10         B
# 6        2120        1/26/10         A
# 7        2120        1/26/10         B
# 8        2038        1/27/10         A
# 9        2038        1/27/10         B

# %%
treatment.tail()
# Out:
#       patient_id treatment_date drug_code
# 1091        2038         2/2/17         A
# 1092        2038         2/6/17         A
# 1093        2038        2/11/17         A
# 1094        2038        2/18/17         A
# 1095        2038        2/20/17         A

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 3 columns):
# patient_id        1096 non-null int64
# treatment_date    1096 non-null object
# drug_code         1096 non-null object
# dtypes: int64(1), object(2)
# memory usage: 25.8+ KB

# %% [markdown]
# ### (1) Distribution of cancer types across clinic's patients.

# %%
series = diagnosis['diagnosis'].value_counts()
series.head()
# Out:
# Breast Cancer    39
# Colon Cancer     18
# Name: diagnosis, dtype: int64

# %%
#Scrolling over each bar gives count for each cancer type, which verifies previous series.head() output.

series.iplot(kind='bar', yTitle='Count', title='Distribution of Cancer Types')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/56.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### (2) How long it takes for patients to start therapy after being diagnosed (quality of care for the patient).

# %% [markdown]
# 1. Verify that patients undergoing treatment are found in diagnosis dataset.
# 2. Join the two tables on patient_id.
# 3. Create a new column that is the difference between treatment diagnosis_date and FIRST treatment_date (will need to format dates).
# 4. Get summary statistics on numerical values (average, min, max).

# %%
# 1. Verify that patients undergoing treatment are found in diagnosis dataset.

check_pat_id_inboth = treatment.patient_id.isin(diagnosis.patient_id)
check_pat_id_inboth.head(10)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: patient_id, dtype: bool

# %%
#Check if above series is all True by counting all distinct groups

check_pat_id_inboth.value_counts()
# Out:
# True    1096
# Name: patient_id, dtype: int64

# %% [markdown]
# After confirming that each diagnosed patient received treatment detailed in treatment dataset, combining both datasets together.

# %%
# 2. Join the two tables on patient_id.

overall_pat =  pd.merge(diagnosis, treatment, on='patient_id', how='outer')

# %%
overall_pat.head()
# Out:
#    patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 0        2120         1/9/10           174.1  Breast Cancer        1/23/10
# 1        2120         1/9/10           174.1  Breast Cancer        1/24/10
# 2        2120         1/9/10           174.1  Breast Cancer        1/26/10
# 3        2120         1/9/10           174.1  Breast Cancer        1/26/10
# 4        2120         1/9/10           174.1  Breast Cancer        1/27/10
#
#   drug_code
# 0         B
# 1         A
# 2         A
# 3         B
# 4         A

# %%
overall_pat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1239 entries, 0 to 1238
# Data columns (total 6 columns):
# patient_id        1239 non-null int64
# diagnosis_date    1239 non-null object
# diagnosis_code    1239 non-null float64
# diagnosis         1239 non-null object
# treatment_date    1237 non-null object
# drug_code         1237 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 67.8+ KB

# %% [markdown]
# Increase in dataframe due to one patient_id in diagnosis dataset matching to multiple patient_id rows in treatment dataset. This is explained by numerous treatment dates/rows per patient.

# %%
overall_pat.head(30)
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 0         2120         1/9/10           174.1  Breast Cancer        1/23/10
# 1         2120         1/9/10           174.1  Breast Cancer        1/24/10
# 2         2120         1/9/10           174.1  Breast Cancer        1/26/10
# 3         2120         1/9/10           174.1  Breast Cancer        1/26/10
# 4         2120         1/9/10           174.1  Breast Cancer        1/27/10
# 5         2120         1/9/10           174.1  Breast Cancer        1/27/10
# 6         2120         1/9/10           174.1  Breast Cancer        1/29/10
# 7         2120         1/9/10           174.1  Breast Cancer        1/29/10
# 8         2120         1/9/10           174.1  Breast Cancer         2/1/10
# 9         2120         1/9/10           174.1  Breast Cancer         2/1/10
# 10        2120         1/9/10           174.1  Breast Cancer         2/4/10
# 11        2120         1/9/10           174.1  Breast Cancer         2/4/10
# 12        2120         1/9/10           174.1  Breast Cancer         2/7/10
# 13        2120         1/9/10           174.1  Breast Cancer         2/7/10
# 14        2120         1/9/10           174.1  Breast Cancer        2/10/10
# 15        2120         1/9/10           174.1  Breast Cancer        2/10/10
# 16        2120         1/9/10           174.1  Breast Cancer        2/14/10
# 17        2120         1/9/10           174.1  Breast Cancer        2/14/10
# 18        2120         1/9/10           174.1  Breast Cancer        2/18/10
# 19        2120         1/9/10           174.1  Breast Cancer        2/18/10
# 20        2120         1/9/10           174.1  Breast Cancer        2/22/10
# 21        2120         1/9/10           174.1  Breast Cancer        2/22/10
# 22        2120         1/9/10           174.1  Breast Cancer        2/27/10
# 23        2120         1/9/10           174.1  Breast Cancer        2/27/10
# 24        2120         1/9/10           174.1  Breast Cancer         3/2/10
# 25        2120         1/9/10           174.1  Breast Cancer         3/2/10
# 26        2720         1/9/10           174.1  Breast Cancer        1/20/10
# 27        2720         1/9/10           174.1  Breast Cancer        1/27/10
# 28        2720         1/9/10           174.1  Breast Cancer         2/3/10
# 29        2720         1/9/10           174.1  Breast Cancer        2/10/10
#
#    drug_code
# 0          B
# 1          A
# 2          A
# 3          B
# 4          A
# 5          B
# 6          A
# 7          B
# 8          A
# 9          B
# 10         A
# 11         B
# 12         A
# 13         B
# 14         A
# 15         B
# 16         A
# 17         B
# 18         A
# 19         B
# 20         A
# 21         B
# 22         A
# 23         B
# 24         A
# 25         B
# 26         B
# 27         B
# 28         B
# 29         B

# %%
#Checking that each patient has its corresponding treatment data and that treatment dates are in ascending order
#Checking for Pat 2120
diagnosis.loc[diagnosis['patient_id'] == 2120]
# Out:
#    patient_id diagnosis_date  diagnosis_code      diagnosis
# 0        2120         1/9/10           174.1  Breast Cancer

# %%
treatment_2120 = treatment.loc[treatment['patient_id'] == 2120]
treatment_2120.head(5)
# Out:
#     patient_id treatment_date drug_code
# 2         2120        1/23/10         B
# 4         2120        1/24/10         A
# 6         2120        1/26/10         A
# 7         2120        1/26/10         B
# 10        2120        1/27/10         A

# %%
treatment_2120.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 2 to 63
# Data columns (total 3 columns):
# patient_id        26 non-null int64
# treatment_date    26 non-null object
# drug_code         26 non-null object
# dtypes: int64(1), object(2)
# memory usage: 832.0+ bytes

# %% [markdown]
# Checked that all treatment rows from a paritcular patient_id (in the this case, #2120) is matched with patient_id from diagnosis dataframe.
# Also, noticed that dates are in chronological order. =)

# %%
# 3. Create a new column that is the difference between treatment diagnosis_date and FIRST treatment_date (will need to format dates).

overall_pat['treatment_date'] = pd.to_datetime(overall_pat['treatment_date'])
overall_pat['treatment_date'].head(5)
# Out:
# 0   2010-01-23
# 1   2010-01-24
# 2   2010-01-26
# 3   2010-01-26
# 4   2010-01-27
# Name: treatment_date, dtype: datetime64[ns]

# %%
overall_pat['diagnosis_date'] = pd.to_datetime(overall_pat['diagnosis_date'])
overall_pat['diagnosis_date'].head(5)
# Out:
# 0   2010-01-09
# 1   2010-01-09
# 2   2010-01-09
# 3   2010-01-09
# 4   2010-01-09
# Name: diagnosis_date, dtype: datetime64[ns]

# %%
#Last column for now being called first_treatment_diagnosis. Following step retains only first treatment date for each patient.
overall_pat['first_treatment-diagnosis']= overall_pat['treatment_date']-overall_pat['diagnosis_date']

# %%
overall_pat.head(30)
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 0         2120     2010-01-09           174.1  Breast Cancer     2010-01-23
# 1         2120     2010-01-09           174.1  Breast Cancer     2010-01-24
# 2         2120     2010-01-09           174.1  Breast Cancer     2010-01-26
# 3         2120     2010-01-09           174.1  Breast Cancer     2010-01-26
# 4         2120     2010-01-09           174.1  Breast Cancer     2010-01-27
# 5         2120     2010-01-09           174.1  Breast Cancer     2010-01-27
# 6         2120     2010-01-09           174.1  Breast Cancer     2010-01-29
# 7         2120     2010-01-09           174.1  Breast Cancer     2010-01-29
# 8         2120     2010-01-09           174.1  Breast Cancer     2010-02-01
# 9         2120     2010-01-09           174.1  Breast Cancer     2010-02-01
# 10        2120     2010-01-09           174.1  Breast Cancer     2010-02-04
# 11        2120     2010-01-09           174.1  Breast Cancer     2010-02-04
# 12        2120     2010-01-09           174.1  Breast Cancer     2010-02-07
# 13        2120     2010-01-09           174.1  Breast Cancer     2010-02-07
# 14        2120     2010-01-09           174.1  Breast Cancer     2010-02-10
# 15        2120     2010-01-09           174.1  Breast Cancer     2010-02-10
# 16        2120     2010-01-09           174.1  Breast Cancer     2010-02-14
# 17        2120     2010-01-09           174.1  Breast Cancer     2010-02-14
# 18        2120     2010-01-09           174.1  Breast Cancer     2010-02-18
# 19        2120     2010-01-09           174.1  Breast Cancer     2010-02-18
# 20        2120     2010-01-09           174.1  Breast Cancer     2010-02-22
# 21        2120     2010-01-09           174.1  Breast Cancer     2010-02-22
# 22        2120     2010-01-09           174.1  Breast Cancer     2010-02-27
# 23        2120     2010-01-09           174.1  Breast Cancer     2010-02-27
# 24        2120     2010-01-09           174.1  Breast Cancer     2010-03-02
# 25        2120     2010-01-09           174.1  Breast Cancer     2010-03-02
# 26        2720     2010-01-09           174.1  Breast Cancer     2010-01-20
# 27        2720     2010-01-09           174.1  Breast Cancer     2010-01-27
# 28        2720     2010-01-09           174.1  Breast Cancer     2010-02-03
# 29        2720     2010-01-09           174.1  Breast Cancer     2010-02-10
#
#    drug_code first_treatment-diagnosis
# 0          B                   14 days
# 1          A                   15 days
# 2          A                   17 days
# 3          B                   17 days
# 4          A                   18 days
# 5          B                   18 days
# 6          A                   20 days
# 7          B                   20 days
# 8          A                   23 days
# 9          B                   23 days
# 10         A                   26 days
# 11         B                   26 days
# 12         A                   29 days
# 13         B                   29 days
# 14         A                   32 days
# 15         B                   32 days
# 16         A                   36 days
# 17         B                   36 days
# 18         A                   40 days
# 19         B                   40 days
# 20         A                   44 days
# 21         B                   44 days
# 22         A                   49 days
# 23         B                   49 days
# 24         A                   52 days
# 25         B                   52 days
# 26         B                   11 days
# 27         B                   18 days
# 28         B                   25 days
# 29         B                   32 days

# %%
care_quality = overall_pat.groupby('patient_id').first()
care_quality
# Out:
#            diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# patient_id
# 2038           2010-01-21           174.9  Breast Cancer     2010-01-24
# 2607               B                   20 days
# 2634               A                  304 days
# 2720               B                   11 days
# 2735               A                    5 days
# 2762               B                    3 days
# 2763               A                    4 days
# 2770               A                    6 days
# 3025               B                    6 days
# 3070               D                    0 days
# 3095               B                    3 days
# 3395               D                    0 days
# 3449               A                    4 days
# 3749               D                    0 days
# 3757               C                   11 days
# 3948               A                    4 days
# 4057               D                    0 days
# 4256             NaN                       NaT
# 4354               A                    5 days
# 4374               C                    5 days
# 4692               A                    3 days
# 5259               A                    4 days
# 5657               A                    5 days
# 6281               A                    4 days
# 6321               A                    4 days
# 6837               B                    5 days
# 6840               B                    5 days
# 6877               C                    7 days
# 6889               A                    8 days
# 6922               C                    7 days
# 7230               C                    7 days
# 7242               B                    6 days
# 7796               A                    5 days
# 7937               A                    6 days
# 7976               A                    5 days
# 8480               A                    6 days
# 8615               B                    6 days
# 8827               A                   -3 days
# 9331               B                    6 days
# 9489               C                    6 days

# %%
care_quality['first_treatment-diagnosis'].describe()
# Out:
# count                         46
# mean     11 days 11:28:41.739130
# std      44 days 06:01:41.221946
# min            -3 days +00:00:00
# 25%              4 days 00:00:00
# 50%              5 days 00:00:00
# 75%              6 days 00:00:00
# max            304 days 00:00:00
# Name: first_treatment-diagnosis, dtype: object

# %%
data = overall_pat['first_treatment-diagnosis']/np.timedelta64(1, 'D')
series2 = data.value_counts()
series2.head()
# Out:
# 40.0    38
# 20.0    38
# 30.0    37
# 24.0    33
# 60.0    32
# Name: first_treatment-diagnosis, dtype: int64

# %%
series2.iplot(kind='bar', xTitle='Number of Days', yTitle='Count', title='First_treatment-Diagnosis (Days)')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/94.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Based on this visualization, we can see that most patients received treatment within 11 days of treatment.

# %%
#Verifying patient_id = 2238 actually started treatment that soon
overall_pat.loc[overall_pat['patient_id'] == 2238]
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 56        2238     2010-01-21           174.9  Breast Cancer     2010-01-21
# 57        2238     2010-01-21           174.9  Breast Cancer     2010-01-31
# 58        2238     2010-01-21           174.9  Breast Cancer     2010-02-10
# 59        2238     2010-01-21           174.9  Breast Cancer     2010-02-20
# 60        2238     2010-01-21           174.9  Breast Cancer     2010-03-02
# 61        2238     2010-01-21           174.9  Breast Cancer     2010-03-12
# 62        2238     2010-01-21           174.9  Breast Cancer     2010-03-22
# 63        2238     2010-01-21           174.9  Breast Cancer     2010-04-01
# 64        2238     2010-01-21           174.9  Breast Cancer     2012-09-18
# 65        2238     2010-01-21           174.9  Breast Cancer     2012-09-28
# 66        2238     2010-01-21           174.9  Breast Cancer     2012-10-08
# 67        2238     2010-01-21           174.9  Breast Cancer     2012-10-18
#
#    drug_code first_treatment-diagnosis
# 56         B                    0 days
# 57         B                   10 days
# 58         B                   20 days
# 59         B                   30 days
# 60         B                   40 days
# 61         B                   50 days
# 62         B                   60 days
# 63         B                   70 days
# 64         B                  971 days
# 65         B                  981 days
# 66         B                  991 days
# 67         B                 1001 days

# %% [markdown]
# This is indicative of great quality of care for there to be no lag between diagnosis and treatment for disease.

# %%
#     drug_code first_treatment-diagnosis
# 470       NaN                       NaT
# 471       NaN                       NaT

# %%
diagnosis.loc[diagnosis['patient_id'] == 4256]
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis
# 24        4256        11/7/11           174.5  Breast Cancer
# 25        4256        11/7/11           174.8  Breast Cancer

# %%
treatment.loc[treatment['patient_id'] == 4256]
# Out:
# Empty DataFrame
# Columns: [patient_id, treatment_date, drug_code]
# Index: []

# %% [markdown]
# Bingo! There is no treatment data for patient_id = 4256. Therefore, the values for treatment_date/first_treatment-diagnosis and drug_code were NaT and NaN.

# %%
#Verifying this by checking original dataframes
diagnosis.loc[diagnosis['patient_id'] == 4256]
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis
# 24        4256        11/7/11           174.5  Breast Cancer
# 25        4256        11/7/11           174.8  Breast Cancer

# %%
treatment.loc[treatment['patient_id'] == 4256]
# Out:
# Empty DataFrame
# Columns: [patient_id, treatment_date, drug_code]
# Index: []

# %%
treatment.isnull().values.any()
# Out:
# False

# %%
#Checking if treatment dataframe had any empty
treatment['patient_id'].empty
# Out:
# False

# %% [markdown]
# If there were no NaN's nor empty records for patient_id 4256, then the record did not exist.
#
# Therefore, this patient's care was non-existant. So his/her care needs to be investigated as well.

# %% [markdown]
# Lastly, reason why patient_id = 8827 has negative value for length of time it takes for patient to start treatment is that doctor probably gave prescrition drugs to try before there was official diagnosis. In this situation, the quality of care appears to be high since the doctor seems to be very vigilant. At the same time, patients who did not receive treatment in a timely manner could have been non-compliant. Regardless of the actual reason, these conclusions need to be factored in when assessing quality of care at this cancer clinic.

# %%
# 4. Get summary statistics on care_quality['treatment-diagnosis'].

care_quality['first_treatment-diagnosis'].describe()
# Out:
# count                         46
# mean     11 days 11:28:41.739130
# std      44 days 06:01:41.221946
# min            -3 days +00:00:00
# 25%              4 days 00:00:00
# 50%              5 days 00:00:00
# 75%              6 days 00:00:00
# max            304 days 00:00:00
# Name: first_treatment-diagnosis, dtype: object

# %% [markdown]
# Conclusion: Patients usually took on average 11 days to start treatment for cancer diagnosis.

# %% [markdown]
# ### (3) Which treatment regimens would be indicated to be used as first-line of treatment for breast cancer and colon cancer?

# %% [markdown]
# According to NCI Dictionary of Cancer Terms, **first-line therapy**:
#
# The first treatment given for a disease. It is often part of a standard set of treatments, such as surgery followed by chemotherapy and radiation. When used by itself, first-line therapy is the one _accepted as the best treatment_. **If it doesn’t cure the disease or it causes severe side effects, other treatment may be added or used instead**.

# %% [markdown]
# Based on the above definition, will find first-line drug for breast cancer and colon cancer by:
# making smaller dataframes from care_quality dataframe for Breast Cancer and Colon Cancer diseases.
# And from these two smaller dataframes, see which drug was used the most and classify that as the first-line therapy.
#
# As a reminder, the dataset that will be used only considers what drug was used on first treatment date for each patient.

# %%
gb =care_quality.groupby('diagnosis')    
[gb.get_group(x) for x in gb.groups]
# Out:
# [           diagnosis_date  diagnosis_code      diagnosis treatment_date  \
#  patient_id
#  2038           2010-01-21           174.9  Breast Cancer     2010-01-24
#  2120           2010-01-09           174.1  Breast Cancer     2010-01-23
# 9489           2013-08-19           174.9  Breast Cancer     2013-08-25
#
#            drug_code first_treatment-diagnosis
# patient_id
# 2038               A                    3 days
# 2120               B                   14 days
# 2175               A                    4 days
# 2238               B                    0 days
# 2407               A                    6 days
# 2425               A                    4 days
# 2462               A                    4 days
# 2475               B                    0 days
# 2607               B                   20 days
# 2720               B                   11 days
# 2735               A                    5 days
# 2762               B                    3 days
# 2763               A                    4 days
# 3025               B                    6 days
# 3757               C                   11 days
# 3948               A                    4 days
# 4256             NaN                       NaT
# 4354               A                    5 days
# 4374               C                    5 days
# 4692               A                    3 days
# 5259               A                    4 days
# 5657               A                    5 days
# 6281               A                    4 days
# 6321               A                    4 days
# 7796               A                    5 days
# 7937               A                    6 days
# 7976               A                    5 days
# 8480               A                    6 days
# 8615               B                    6 days
# 8827               A                   -3 days
# 9331               B                    6 days
# 9489               C                    6 days

# %%
breast_cancer.drug_code.value_counts()
# Out:
# A    19
# B     9
# C     3
# Name: drug_code, dtype: int64

# %%
data = breast_cancer['drug_code']
series3 = data.value_counts()
series3.head()

series3.iplot(kind='bar', xTitle='drug_code', yTitle='Count', title='Breast Cancer - Line of Treatment')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/102.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# For Breast Cancer diagnosis, the most common used drug is A. If it is the most common, then it must be the most affective with patients having Breast Cancer. Given, based on first-line therapy definition, the most indicative drug for first-line therapy is drug A.

# %%
#Now, Colon Cancer treatment is analyzed.
colon_cancer = [gb.get_group(x) for x in gb.groups][1]
colon_cancer
# Out:
#            diagnosis_date  diagnosis_code     diagnosis treatment_date  \
# patient_id
# 2634           2011-02-19           153.9  Colon Cancer     2011-12-20
# 2770           2011-04-16           153.9  Colon Cancer     2011-04-22
# 3070           2011-07-25           153.9  Colon Cancer     2011-07-25
# 3095           2011-07-10           153.3  Colon Cancer     2011-07-13
# 3395           2011-10-18           153.3  Colon Cancer     2011-10-18
# 3449           2011-09-09           153.5  Colon Cancer     2011-09-13
# 3749           2011-12-18           153.5  Colon Cancer     2011-12-18
# 4057           2012-01-25           153.4  Colon Cancer     2012-01-25
# 6837           2012-10-20           153.3  Colon Cancer     2012-10-25
# 6840           2012-11-15           153.4  Colon Cancer     2012-11-20
# 6877           2012-11-26           153.4  Colon Cancer     2012-12-03
# 6889           2012-11-14           153.7  Colon Cancer     2012-11-22
# 6922           2012-11-15           153.6  Colon Cancer     2012-11-22
# 7230           2013-01-02           153.8  Colon Cancer     2013-01-09
# 7242           2013-01-17           153.5  Colon Cancer     2013-01-23
#
#            drug_code first_treatment-diagnosis
# patient_id
# 2634               A                  304 days
# 2770               A                    6 days
# 3070               D                    0 days
# 3095               B                    3 days
# 3395               D                    0 days
# 3449               A                    4 days
# 3749               D                    0 days
# 4057               D                    0 days
# 6837               B                    5 days
# 6840               B                    5 days
# 6877               C                    7 days
# 6889               A                    8 days
# 6922               C                    7 days
# 7230               C                    7 days
# 7242               B                    6 days

# %%
colon_cancer.drug_code.value_counts()
# Out:
# B    4
# D    4
# A    4
# C    3
# Name: drug_code, dtype: int64

# %%
data = colon_cancer['drug_code']
series4 = data.value_counts()
series4.head()

series4.iplot(kind='bar', xTitle='drug_code', yTitle='Count', title='Colon Cancer - Line of Treatment')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/104.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Here, the distribution is not as skewed. So there seems to be no drug that is predominantly chosen as the first one for treatment based on value counts for each drug. Though, there has to be a reason that the drug_codes are sorted in the manner it is rather than in A, B, C, D format. When looking closer at when each drug is given, can see preference of which drug is chosen based on number of days between diagnosis and treatment.
#
# Drug D has a time difference of 0 from treatment date to diagnosis date. This means this is the chosen drug when diagnosis is first given. It indicates an aggressive treatment possibly for late stage Colon Cancer patients. Remaining drugs: A, B and C all have average of 6, 6.3 and 7 days (discounting outlier) from diagnosis date to treatment date. This means that these drugs are possibly given to Colon Cancer patients a week out from diagnosis poaaibly due to not having late stage Colon Cancer.

# %% [markdown]
# ### (4) Do the patients taking Regimen A vs. Regimen B as first-line thereapy for Breast Cancer vary in terms of duration of therapy?

# %% [markdown]
# 1. Look at each Breast Cancer patient only, and see if they have Regimen A/Regimen B as first-line therapy.
# 2. Then for each of these patients, on top of having first day of treatment for Regimen A/B, need to grab last day of treatment for given Regimen A/B.
# 3. Get difference between these dates.
# 4. Compare differences in Regimen A versus Regimen B.
#     a. Preliminary assessment: Can get overall stat's on new column to get mean and standard deviations at 25%, 50% and 75%.
#     b. Final assessment: Perform paired t-test to assess differnce in duration of therapy between Regimen A and Regimen B.

# %%
#As reminder, here is the df with all treatment dates per patient. The first and last treatment dates need to be grabbed from this.
overall_pat2 = overall_pat.drop(['first_treatment-diagnosis'], axis = 1)
overall_pat2.head(5)
# Out:
#    patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 0        2120     2010-01-09           174.1  Breast Cancer     2010-01-23
# 1        2120     2010-01-09           174.1  Breast Cancer     2010-01-24
# 2        2120     2010-01-09           174.1  Breast Cancer     2010-01-26
# 3        2120     2010-01-09           174.1  Breast Cancer     2010-01-26
# 4        2120     2010-01-09           174.1  Breast Cancer     2010-01-27
#
#   drug_code
# 0         B
# 1         A
# 2         A
# 3         B
# 4         A

# %%
#Separating out Breast Cancer diagnosis from Colon Cancer diagnosis
gb2 =overall_pat2.groupby('diagnosis')    
[gb2.get_group(x) for x in gb2.groups]
# Out:
# [      patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
#  0           2120     2010-01-09           174.1  Breast Cancer     2010-01-23
#  1           2120     2010-01-09           174.1  Breast Cancer     2010-01-24
#  2           2120     2010-01-09           174.1  Breast Cancer     2010-01-26
#  3           2120     2010-01-09           174.1  Breast Cancer     2010-01-26
#  4           2120     2010-01-09           174.1  Breast Cancer     2010-01-27
#  5           2120     2010-01-09           174.1  Breast Cancer     2010-01-27
#  6           2120     2010-01-09           174.1  Breast Cancer     2010-01-29
#  7           2120     2010-01-09           174.1  Breast Cancer     2010-01-29
#  8           2120     2010-01-09           174.1  Breast Cancer     2010-02-01
#  9           2120     2010-01-09           174.1  Breast Cancer     2010-02-01
#  10          2120     2010-01-09           174.1  Breast Cancer     2010-02-04
#  11          2120     2010-01-09           174.1  Breast Cancer     2010-02-04
#  12          2120     2010-01-09           174.1  Breast Cancer     2010-02-07
#  1096        7242     2013-01-17           153.5  Colon Cancer     2013-08-03
#  1097        7242     2013-01-17           153.5  Colon Cancer     2013-08-09
#  1098        7242     2013-01-17           153.5  Colon Cancer     2013-08-15
#  1099        7242     2013-01-17           153.5  Colon Cancer     2013-08-21
#  1100        7242     2013-01-17           153.5  Colon Cancer     2013-08-27
#  1101        7242     2013-01-17           153.5  Colon Cancer     2013-09-02
#  1102        7242     2013-01-17           153.5  Colon Cancer     2013-09-08
#  1103        7242     2013-01-17           153.5  Colon Cancer     2013-09-14
#  1104        7242     2013-01-17           153.5  Colon Cancer     2013-09-20
#  1105        7242     2013-01-17           153.5  Colon Cancer     2013-10-10
#  1106        7242     2013-01-17           153.5  Colon Cancer     2013-10-30
#  1107        7242     2013-01-17           153.5  Colon Cancer     2013-11-19
#  1108        7242     2013-01-17           153.5  Colon Cancer     2013-12-09
#  1109        7242     2013-01-17           153.5  Colon Cancer     2013-12-29
#  1110        7242     2013-01-17           153.5  Colon Cancer     2014-01-18
#  1111        7242     2013-01-17           153.5  Colon Cancer     2014-02-07
#  1112        7242     2013-01-17           153.5  Colon Cancer     2014-02-27
#  1113        7242     2013-01-17           153.5  Colon Cancer     2014-03-19
#  1114        7242     2013-01-17           153.5  Colon Cancer     2014-04-08
#  1115        7242     2013-01-17           153.5  Colon Cancer     2014-04-28
#  1116        7242     2013-01-17           153.5  Colon Cancer     2014-05-18
#  1117        7242     2013-01-17           153.5  Colon Cancer     2014-06-07
#  1118        7242     2013-01-17           153.5  Colon Cancer     2014-06-27
#  1119        7242     2013-01-17           153.5  Colon Cancer     2014-07-17
#  1120        7242     2013-01-17           153.5  Colon Cancer     2014-08-06
#  1121        7242     2013-01-17           153.5  Colon Cancer     2014-08-26
#  1122        7242     2013-01-17           153.5  Colon Cancer     2014-09-15
#  1123        7242     2013-01-17           153.5  Colon Cancer     2014-10-05
#  1124        7242     2013-01-17           153.5  Colon Cancer     2014-10-25
#
#       drug_code
#  216          A
#  217          B
#  218          A
#  219          B
#  220          A
#  221          B
#  222          A
#  223          B
#  224          A
#  225          B
#  226          A
#  227          B
#  228          A
#  229          B
#  230          A
#  231          B
#  232          A
#  233          B
#  234          A
#  235          B
#  236          A
#  237          B
#  238          A
#  239          B
#  240          A
#  241          B
#  242          A
#  243          B
#  244          A
#  245          B
#  ...        ...
#  1095         C
#  1096         C
#  1097         C
#  1098         C
#  1099         C
#  1100         C
#  1101         C
#  1102         C
#  1103         C
#  1104         C
#  1105         C
#  1106         C
#  1107         C
#  1108         C
#  1109         C
#  1110         C
#  1111         C
#  1112         C
#  1113         C
#  1114         C
#  1115         C
#  1116         C
#  1117         C
#  1118         C
#  1119         C
#  1120         C
#  1121         C
#  1122         C
#  1123         C
#  1124         C
#
#  [375 rows x 6 columns]]

# %%
#Breast Cancer patient data only
breast_cancer_pats = [gb2.get_group(x) for x in gb2.groups][0]
breast_cancer_pats.head(5)
# Out:
#    patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 0        2120     2010-01-09           174.1  Breast Cancer     2010-01-23
#  1189        8827     2013-07-21           174.9  Breast Cancer     2013-09-24
#  1190        8827     2013-07-21           174.9  Breast Cancer     2013-09-29
#  1191        8827     2013-07-21           174.9  Breast Cancer     2013-10-04
#  1192        8827     2013-07-21           174.9  Breast Cancer     2013-10-09
#  1193        8827     2013-07-21           174.9  Breast Cancer     2013-10-14
#  1194        8827     2013-07-21           174.9  Breast Cancer     2013-10-19
#  1205        9331     2013-08-23           174.9  Breast Cancer     2013-08-29
#  1207        9331     2013-08-23           174.9  Breast Cancer     2013-09-04
#  1209        9331     2013-08-23           174.9  Breast Cancer     2013-09-10
#  1211        9331     2013-08-23           174.9  Breast Cancer     2013-09-16
#  1213        9331     2013-08-23           174.9  Breast Cancer     2013-09-22
#  1214        9331     2013-08-23           174.9  Breast Cancer     2013-09-28
#  1215        9331     2013-08-23           174.9  Breast Cancer     2013-10-04
#  1216        9331     2013-08-23           174.9  Breast Cancer     2013-10-10
#  1217        9331     2013-08-23           174.9  Breast Cancer     2013-10-16
#  1218        9331     2013-08-23           174.9  Breast Cancer     2013-10-22
#  1219        9331     2013-08-23           174.9  Breast Cancer     2013-10-28
#  1220        9331     2013-08-23           174.9  Breast Cancer     2013-11-03
#  1221        9331     2013-08-23           174.9  Breast Cancer     2013-11-09
#  1222        9331     2013-08-23           174.9  Breast Cancer     2013-11-15
#  1223        9331     2013-08-23           174.9  Breast Cancer     2013-11-21
#  1224        9331     2013-08-23           174.9  Breast Cancer     2013-11-27
#  1225        9331     2013-08-23           174.9  Breast Cancer     2013-12-02
#
#       drug_code
#  1            A
#  2            A
#  4            A
#  6            A
#  8            A
#  10           A
#  12           A
#  14           A
#  16           A
#  18           A
#  20           A
#  22           A
#  24           A
#  37           A
#  39           A
#  41           A
#  43           A
#  44           A
#  45           A
#  46           A
#  47           A
#  48           A
#  49           A
#  50           A
#  51           A
#  52           A
#  53           A
#  54           A
#  55           A
#  68           A
#  ...        ...
#  1182         A
#  1183         A
#  1184         A
#  1185         A
#  1186         A
#  1187         A
#  1188         A
#  1189         A
#  1190         A
#  1191         A
#  1192         A
#  1193         A
#  1194         A
#  1205         A
#  1207         A
#  1209         A
#  1211         A
#  1213         A
#  1214         A
#  1215         A
#  1216         A
#  1217         A
#  1218         A
#  1219         A
#  1220         A
#  1221         A
#  1222         A
#  1223         A
#  1224         A
#  1225         A
#
#  [333 rows x 6 columns],
#        patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
#  0           2120     2010-01-09           174.1  Breast Cancer     2010-01-23
#  3           2120     2010-01-09           174.1  Breast Cancer     2010-01-26
#  5           2120     2010-01-09           174.1  Breast Cancer     2010-01-27
#  7           2120     2010-01-09           174.1  Breast Cancer     2010-01-29
#  9           2120     2010-01-09           174.1  Breast Cancer     2010-02-01
#  11          2120     2010-01-09           174.1  Breast Cancer     2010-02-04
#  13          2120     2010-01-09           174.1  Breast Cancer     2010-02-07
#  15          2120     2010-01-09           174.1  Breast Cancer     2010-02-10
#  17          2120     2010-01-09           174.1  Breast Cancer     2010-02-14
#  19          2120     2010-01-09           174.1  Breast Cancer     2010-02-18
#  1206        9331     2013-08-23           174.9  Breast Cancer     2013-09-04
#  1208        9331     2013-08-23           174.9  Breast Cancer     2013-09-10
#  1210        9331     2013-08-23           174.9  Breast Cancer     2013-09-16
#  1212        9331     2013-08-23           174.9  Breast Cancer     2013-09-22
#
#       drug_code
#  0            B
#  3            B
#  5            B
#  7            B
#  9            B
#  11           B
#  13           B
#  15           B
#  17           B
#  19           B
#  21           B
#  23           B
#  25           B
#  26           B
#  27           B
#  28           B
#  29           B
#  30           B
#  31           B
#  32           B
#  33           B
#  34           B
#  35           B
#  36           B
#  38           B
#  40           B
#  42           B
#  56           B
#  57           B
#  58           B
#  ...        ...
#  824          B
#  826          B
#  828          B
#  830          B
#  832          B
#  834          B
#  836          B
#  838          B
#  905          B
#  907          B
#  909          B
#  1036         B
#  1038         B
#  1040         B
#  1042         B
#  1044         B
#  1046         B
#  1048         B
#  1155         B
#  1157         B
#  1159         B
#  1161         B
#  1163         B
#  1165         B
#  1167         B
#  1204         B
#  1206         B
#  1208         B
#  1210         B
#  1212         B
#
#  [293 rows x 6 columns],
#        patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
#  411         3757     2011-10-11           174.1  Breast Cancer     2011-10-22
#  412         3757     2011-10-11           174.1  Breast Cancer     2011-10-27
#  413         3757     2011-10-11           174.1  Breast Cancer     2011-11-01
#  414         3757     2011-10-11           174.1  Breast Cancer     2011-11-06
#  415         3757     2011-10-11           174.1  Breast Cancer     2011-11-11
#  416         3757     2011-10-11           174.1  Breast Cancer     2011-11-16
#  417         3757     2011-10-11           174.1  Breast Cancer     2011-11-21
#  418         3757     2011-10-11           174.1  Breast Cancer     2011-11-26
#  419         3757     2011-10-11           174.1  Breast Cancer     2011-12-01
#  420         3757     2011-10-11           174.1  Breast Cancer     2011-12-06
#  421         3757     2011-10-11           174.1  Breast Cancer     2011-12-11
#  422         3757     2011-10-11           174.1  Breast Cancer     2011-12-16
#  423         3757     2011-10-11           174.1  Breast Cancer     2011-12-21
#  424         3757     2011-10-11           174.1  Breast Cancer     2011-12-26
#  425         3757     2011-10-11           174.1  Breast Cancer     2011-12-31
#  426         3757     2011-10-11           174.1  Breast Cancer     2012-01-05
#  427         3757     2011-10-11           174.1  Breast Cancer     2012-01-10
#  428         3757     2011-10-11           174.1  Breast Cancer     2012-01-17
#  504         3948     2011-12-18           174.6  Breast Cancer     2012-03-03
#  505         3948     2011-12-18           174.6  Breast Cancer     2012-03-13
#  506         3948     2011-12-18           174.6  Breast Cancer     2012-03-23
#  507         3948     2011-12-18           174.6  Breast Cancer     2012-04-02
#  508         3948     2011-12-18           174.6  Breast Cancer     2012-04-12
#  509         3948     2011-12-18           174.6  Breast Cancer     2012-04-22
#  510         3948     2011-12-18           174.6  Breast Cancer     2012-05-02
#  511         3948     2011-12-18           174.6  Breast Cancer     2012-05-12
#  512         3948     2011-12-18           174.6  Breast Cancer     2012-05-27
#  533         4354     2012-02-04           174.8  Breast Cancer     2012-03-05
#  534         4354     2012-02-04           174.8  Breast Cancer     2012-03-10
#  535         4354     2012-02-04           174.8  Breast Cancer     2012-03-15
#  ...          ...            ...             ...            ...            ...
#  1014        7230     2013-01-06           174.9  Breast Cancer     2013-02-13
#  1015        7230     2013-01-06           174.9  Breast Cancer     2013-02-20
#  1016        7230     2013-01-06           174.9  Breast Cancer     2013-02-27
#  1017        7230     2013-01-06           174.9  Breast Cancer     2013-03-06
#  1018        7230     2013-01-06           174.9  Breast Cancer     2013-03-13
#  1019        7230     2013-01-06           174.9  Breast Cancer     2013-03-20
#  1020        7230     2013-01-06           174.9  Breast Cancer     2013-03-27
#  1021        7230     2013-01-06           174.9  Breast Cancer     2013-04-03
#  1195        9489     2013-08-19           174.9  Breast Cancer     2013-08-25
#  1196        9489     2013-08-19           174.9  Breast Cancer     2013-08-31
#  1197        9489     2013-08-19           174.9  Breast Cancer     2013-09-06
#  1198        9489     2013-08-19           174.9  Breast Cancer     2013-09-12
#  1199        9489     2013-08-19           174.9  Breast Cancer     2013-09-18
#  1200        9489     2013-08-19           174.9  Breast Cancer     2013-09-24
#  1201        9489     2013-08-19           174.9  Breast Cancer     2013-09-30
#  1202        9489     2013-08-19           174.9  Breast Cancer     2013-10-06
#  1203        9489     2013-08-19           174.9  Breast Cancer     2013-10-11
#  1226        9331     2013-08-23           174.9  Breast Cancer     2013-12-09
#  1227        9331     2013-08-23           174.9  Breast Cancer     2013-12-17
#  1228        9331     2013-08-23           174.9  Breast Cancer     2013-12-25
#  1229        9331     2013-08-23           174.9  Breast Cancer     2014-01-02
#  1230        9331     2013-08-23           174.9  Breast Cancer     2014-01-10
#  1231        9331     2013-08-23           174.9  Breast Cancer     2014-01-18
#  1232        9331     2013-08-23           174.9  Breast Cancer     2014-01-26
#  1233        9331     2013-08-23           174.9  Breast Cancer     2014-02-03
#  1234        9331     2013-08-23           174.9  Breast Cancer     2014-02-11
#  1235        9331     2013-08-23           174.9  Breast Cancer     2014-02-19
#  1236        9331     2013-08-23           174.9  Breast Cancer     2014-02-27
#  1237        9331     2013-08-23           174.9  Breast Cancer     2014-03-07
#  1238        9331     2013-08-23           174.9  Breast Cancer     2014-03-11
#
#       drug_code
#  411          C
#  412          C
#  413          C
#  414          C
#  415          C
#  416          C
#  417          C
#  418          C
#  419          C
#  420          C
#  421          C
#  422          C
#  423          C
#  424          C
#  425          C
#  426          C
#  427          C
#  428          C
#  504          C
#  505          C
#  506          C
#  507          C
#  508          C
#  509          C
#  510          C
#  511          C
#  512          C
#  533          C
#  534          C
#  535          C
#  ...        ...
#  1014         C
#  1015         C
#  1016         C
#  1017         C
#  1018         C
#  1019         C
#  1020         C
#  1021         C
#  1195         C
#  1196         C
#  1197         C
#  1198         C
#  1199         C
#  1200         C
#  1201         C
#  1202         C
#  1203         C
#  1226         C
#  1227         C
#  1228         C
#  1229         C
#  1230         C
#  1231         C
#  1232         C
#  1233         C
#  1234         C
#  1235         C
#  1236         C
#  1237         C
#  1238         C
#
#  [236 rows x 6 columns]]

# %%
#Breast Cancer patients with Regimen A treatment dates
breast_cancer_drugA = [gb3.get_group(x) for x in gb3.groups][0]
breast_cancer_drugA.head(5)
# Out:
#    patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 1        2120     2010-01-09           174.1  Breast Cancer     2010-01-24
# 2        2120     2010-01-09           174.1  Breast Cancer     2010-01-26
# 4        2120     2010-01-09           174.1  Breast Cancer     2010-01-27
# 6        2120     2010-01-09           174.1  Breast Cancer     2010-01-29
# 8        2120     2010-01-09           174.1  Breast Cancer     2010-02-01
#
#   drug_code
# 1         A
# 2         A
# 4         A
# 6         A
# 8         A

# %%
#Breast Cancer patients with Regimen B treatment dates
breast_cancer_drugB = [gb3.get_group(x) for x in gb3.groups][1]
breast_cancer_drugB.head(30)
# Out:
#     patient_id diagnosis_date  diagnosis_code      diagnosis treatment_date  \
# 0         2120     2010-01-09           174.1  Breast Cancer     2010-01-23
# 3         2120     2010-01-09           174.1  Breast Cancer     2010-01-26
# 5         2120     2010-01-09           174.1  Breast Cancer     2010-01-27
# 7         2120     2010-01-09           174.1  Breast Cancer     2010-01-29
# 9         2120     2010-01-09           174.1  Breast Cancer     2010-02-01
# 11        2120     2010-01-09           174.1  Breast Cancer     2010-02-04
# 13        2120     2010-01-09           174.1  Breast Cancer     2010-02-07
# 15        2120     2010-01-09           174.1  Breast Cancer     2010-02-10
# 17        2120     2010-01-09           174.1  Breast Cancer     2010-02-14
# 19        2120     2010-01-09           174.1  Breast Cancer     2010-02-18
# 21        2120     2010-01-09           174.1  Breast Cancer     2010-02-22
# 23        2120     2010-01-09           174.1  Breast Cancer     2010-02-27
# 25        2120     2010-01-09           174.1  Breast Cancer     2010-03-02
# 26        2720     2010-01-09           174.1  Breast Cancer     2010-01-20
# 27        2720     2010-01-09           174.1  Breast Cancer     2010-01-27
# 28        2720     2010-01-09           174.1  Breast Cancer     2010-02-03
# 29        2720     2010-01-09           174.1  Breast Cancer     2010-02-10
# 30        2720     2010-01-09           174.1  Breast Cancer     2010-02-12
# 31        2720     2010-01-09           174.1  Breast Cancer     2010-02-19
# 32        2720     2010-01-09           174.1  Breast Cancer     2010-02-28
# 33        2720     2010-01-09           174.1  Breast Cancer     2010-03-07
# 34        2720     2010-01-09           174.1  Breast Cancer     2010-03-17
# 35        2720     2010-01-09           174.1  Breast Cancer     2010-03-27
# 36        2720     2010-01-09           174.1  Breast Cancer     2010-04-06
# 38        2038     2010-01-21           174.9  Breast Cancer     2010-01-24
# 40        2038     2010-01-21           174.9  Breast Cancer     2010-01-27
# 42        2038     2010-01-21           174.9  Breast Cancer     2010-01-30
# 56        2238     2010-01-21           174.9  Breast Cancer     2010-01-21
# 57        2238     2010-01-21           174.9  Breast Cancer     2010-01-31
# 58        2238     2010-01-21           174.9  Breast Cancer     2010-02-10
#
#    drug_code
# 0          B
# 3          B
# 5          B
# 7          B
# 9          B
# 11         B
# 13         B
# 15         B
# 17         B
# 19         B
# 21         B
# 23         B
# 25         B
# 26         B
# 27         B
# 28         B
# 29         B
# 30         B
# 31         B
# 32         B
# 33         B
# 34         B
# 35         B
# 36         B
# 38         B
# 40         B
# 42         B
# 56         B
# 57         B
# 58         B

# %%
#For each patient_id, get only first and last day of treatment for drug: A

treatment_duration_A = breast_cancer_drugA.groupby('patient_id').nth([0,-1])
treatment_duration_A.head(5)
# Out:
#                 diagnosis  diagnosis_code diagnosis_date drug_code  \
# patient_id
# 2038        Breast Cancer           174.9     2010-01-21         A
# 2038        Breast Cancer           174.9     2010-01-21         A
# 2120        Breast Cancer           174.1     2010-01-09         A
# 2120        Breast Cancer           174.1     2010-01-09         A
# 2175        Breast Cancer           174.7     2010-02-17         A
#
#            treatment_date
# patient_id
# 2038           2010-01-24
# 2038           2017-02-20
# 2120           2010-01-24
# 2120           2010-03-02
# 2175           2010-02-21

# %%
#For each patient_id, get only first and last day of treatment for drug: B

treatment_duration_B = breast_cancer_drugB.groupby('patient_id').nth([0,-1])
treatment_duration_B.head(5)
# Out:
#                 diagnosis  diagnosis_code diagnosis_date drug_code  \
# patient_id
# 2038        Breast Cancer           174.9     2010-01-21         B
# 2038        Breast Cancer           174.9     2010-01-21         B
# 2120        Breast Cancer           174.1     2010-01-09         B
# 2120        Breast Cancer           174.1     2010-01-09         B
# 2175        Breast Cancer           174.7     2010-02-17         B
#
#            treatment_date
# patient_id
# 2038           2010-01-24
# 2038           2010-01-30
# 2120           2010-01-23
# 2120           2010-03-02
# 2175           2010-02-21

# %%
#Getting difference in days between first and last treatment dates for Regimen A

treatment_dur_A = treatment_duration_A.groupby(['patient_id'])['treatment_date'].agg(lambda x: (abs(x.iloc[-1] - x.iloc[0])))
treatment_dur_A
# Out:
# patient_id
# 2038   2584 days
# 2120     37 days
# 2175     41 days
# 2407     45 days
# 2425     51 days
# 2462     52 days
# 2735     53 days
# 2763     60 days
# 3948     62 days
# 4354     20 days
# 4692     42 days
# 5259     63 days
# 5657     63 days
# 6281     69 days
# 6321     70 days
# 6889     24 days
# 7796     69 days
# 7937     74 days
# 7976     77 days
# 8480     77 days
# 8615     80 days
# 8827     93 days
# 9331     95 days
# Name: treatment_date, dtype: timedelta64[ns]

# %%
data = treatment_dur_A/np.timedelta64(1, 'D')
series5 = data.value_counts()
series5.head()

series5.iplot(kind='bar', xTitle='Patients Reindexed', yTitle='Count', title='Regimen A - Treatment Duration')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/106.embed" height="525px" width="100%"></iframe>

# %%
#Getting difference in days between first and last treatment dates for Regimen B

treatment_dur_B = treatment_duration_B.groupby(['patient_id'])['treatment_date'].agg(lambda x: (abs(x.iloc[-1] - x.iloc[0])))
treatment_dur_B
# Out:
# patient_id
# 2038      6 days
# 2120     38 days
# 2175     41 days
# 2238   1001 days
# 2407     45 days
# 2425     51 days
# 2462     52 days
# 2475      0 days
# 2607     74 days
# 2720     76 days
# 2735     53 days
# 2762     76 days
# 2763     60 days
# 3025     77 days
# 3948     62 days
# 4354     20 days
# 4692     42 days
# 5259     63 days
# 5657     63 days
# 6281     69 days
# 6321     70 days
# 6889     32 days
# 7796     30 days
# 8615     36 days
# 9331     24 days
# Name: treatment_date, dtype: timedelta64[ns]

# %%
data = treatment_dur_B/np.timedelta64(1, 'D')
series6 = data.value_counts()
series6.head()

series6.iplot(kind='bar', xTitle='Patients Reindexed', yTitle='Count', title='Regimen B - Treatment Duration')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/108.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Treatment duration distribution between Regimen A and Regimen B look very similar, but in order to get a closer look, need to look at the overall statistics to make assessment less subjective.

# %%
#Preliminary assessment of Regimen A treatment duration/patient

treatment_dur_A.describe()
# Out:
# count                          23
# mean     169 days 14:36:31.304347
# std      526 days 16:15:03.638398
# min              20 days 00:00:00
# 25%              48 days 00:00:00
# 50%              63 days 00:00:00
# 75%              75 days 12:00:00
# max            2584 days 00:00:00
# Name: treatment_date, dtype: object

# %%
#Preliminary assessment of Regimen B treatment duration/patient

treatment_dur_B.describe()
# Out:
# count                          25
# mean             86 days 10:33:36
# std      191 days 18:04:47.809755
# min               0 days 00:00:00
# 25%              36 days 00:00:00
# 50%              52 days 00:00:00
# 75%              69 days 00:00:00
# max            1001 days 00:00:00
# Name: treatment_date, dtype: object

# %% [markdown]
# It is easy to compare descriptive statistics describing central tendency (mean), dispersion (standard deviations at different levels), but a more accurate comparison will come through a paired t-test.
#
# A paired t-test, sometimes called the dependent sample t-test, is a statistical procedure used to determine whether the mean difference between two sets of observations is zero. In a paired sample t-test, each subject or entity is measured twice, resulting in pairs of observations.
#
# So let us set one up.

# %% [markdown]
# Hypotheses:
#
# • The null hypothesis (H0) assumes that the true mean difference (μd) is equal to zero.
# • The two-tailed alternative hypothesis (Ha) assumes that μd is not equal to zero.
# • The upper-tailed alternative hypothesis (Ha) assumes that μd is greater than zero.
# • The lower-tailed alternative hypothesis (Ha) assumes that μd is less than zero.
#
# Assumptions:
#
# • The dependent variable must be continuous (interval/ratio).
# • The observations are independent of one another.
# • The dependent variable should be approximately normally distributed.
# • The dependent variable should not contain any outliers.
#
# In order to perform a paired t-test:
#
# 1. Calculate the sample mean.
#
# 2. Calculate the sample standard deviation.
#
# 3. Calculate the test statistic.
#
# 4. Calculate the probability of observing the test statistic under the null hypothesis. This value is obtained by comparing t to a t-distribution with (n − 1) degrees of freedom. This can be done by looking up the value in a table, such as those found in many statistical textbooks, or with statistical software for more accurate results.
#
# p = 2 ⋅ Pr(T > |t|)    (two-tailed)
# p = Pr(T > t)          (upper-tailed)
# p = Pr(T < t)          (lower-tailed)
#
# Determine whether the results provide sufficient evidence to reject the null hypothesis in favor of the alternative hypothesis.

# %%
#Need to convert time data into plotly friendly format to perform paired t-test

#Use: pd.to_numeric

# %%
twosample_results = scipy.stats.ttest_ind(pd.to_numeric(treatment_dur_A) , pd.to_numeric(treatment_dur_B))

matrix_twosample = [
    ['', 'Test Statistic', 'p-value'],
    ['Treatment Duration Data', twosample_results[0], twosample_results[1]]
]

twosample_table = FF.create_table(matrix_twosample, index=True)
py.iplot(twosample_table)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mindyng/85.embed" height="110px" width="100%"></iframe>

# %% [markdown]
# Since our p-value is less than our Test Statistic, then with evidence we can reject our null hypothesis of identical means. This is in alignment with our setup, since we sampled from two different normal pdfs with different means (169 days for Regimen A versus 86 days for Regimen B).
#
# Therefore, if length of drug treatment is indicative of its efficacy, meaning longer length of therapy means more favored/more affective drug, then Regimen A would be drug of choice for Breast Cancer patients from this particular population.
